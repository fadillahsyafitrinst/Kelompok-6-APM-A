# %%
import pandas as pd
import numpy as np
import json
import nltk
import re
import csv
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from tqdm import tqdm
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from collections import Counter
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
data = pd.read_csv('mpst_full_data.csv', sep=',')
data.head()
# Out:
#      imdb_id                                          title  \
# 0  tt0057603                        I tre volti della paura
# 1  tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2  tt0033045                     The Shop Around the Corner
# 3  tt0113862                             Mr. Holland's Opus
# 4  tt0086250                                       Scarface
#
#                                        plot_synopsis  \
# 0  Note: this synopsis is for the orginal Italian...
# 1  Two thousand years ago, Nhagruul the Foul, a s...
# 2  Matuschek's, a gift store in Budapest, is the ...
# 3  Glenn Holland, not a morning person by anyone'...
# 4  In May 1980, a Cuban man named Tony Montana (A...
#
#                                                 tags  split synopsis_source
# 0          cult, horror, gothic, murder, atmospheric  train            imdb
# 1                                           violence  train            imdb
# 2                                           romantic   test            imdb
# 3             inspiring, romantic, stupid, feel-good  train            imdb
# 4  cruelty, murder, dramatic, cult, violence, atm...    val            imdb

# %%
data.describe()
# Out:
#           imdb_id                 title  \
# count       14828                 14828
# unique      14828                 13757
# top     tt0494232  Beauty and the Beast
# freq            1                    10
#
#                                             plot_synopsis    tags  split  \
# count                                               14828   14828  14828
# unique                                              13848    5604      3
# top     Dragon Ball Z picks up five years after the en...  murder  train
# freq                                                   12    1004   9489
#
#        synopsis_source
# count            14828
# unique               2
# top          wikipedia
# freq             10656

# %%
data.isnull().sum()
# Out:
# imdb_id            0
# title              0
# plot_synopsis      0
# tags               0
# split              0
# synopsis_source    0
# dtype: int64

# %%
imdb_id = data.imdb_id
plot = data.plot_synopsis

movies = pd.DataFrame({'imdb_id': imdb_id, 'plot': plot})
movies.head()
# Out:
#      imdb_id                                               plot
# 0  tt0057603  Note: this synopsis is for the orginal Italian...
# 1  tt1733125  Two thousand years ago, Nhagruul the Foul, a s...
# 2  tt0033045  Matuschek's, a gift store in Budapest, is the ...
# 3  tt0113862  Glenn Holland, not a morning person by anyone'...
# 4  tt0086250  In May 1980, a Cuban man named Tony Montana (A...

# %%
data['imdb_id'] = data['imdb_id'].astype(str)
movies = pd.merge(movies, data[['imdb_id', 'title', 'tags', 'split']], on='imdb_id')
movies.head()
# Out:
#      imdb_id                                               plot  \
# 0  tt0057603  Note: this synopsis is for the orginal Italian...
# 1  tt1733125  Two thousand years ago, Nhagruul the Foul, a s...
# 2  tt0033045  Matuschek's, a gift store in Budapest, is the ...
# 3  tt0113862  Glenn Holland, not a morning person by anyone'...
# 4  tt0086250  In May 1980, a Cuban man named Tony Montana (A...
#
#                                            title  \
# 0                        I tre volti della paura
# 1  Dungeons & Dragons: The Book of Vile Darkness
# 2                     The Shop Around the Corner
# 3                             Mr. Holland's Opus
# 4                                       Scarface
#
#                                                 tags  split
# 0          cult, horror, gothic, murder, atmospheric  train
# 1                                           violence  train
# 2                                           romantic   test
# 3             inspiring, romantic, stupid, feel-good  train
# 4  cruelty, murder, dramatic, cult, violence, atm...    val

# %%
genres_listas = []

for tag in movies.tags:
    genres_listas.append(re.split(',', tag))

movies.tags = genres_listas

# %%
all_genres = sum(genres_listas, [])
for i in range(0, len(all_genres)):
    all_genres[i] = all_genres[i].strip()
print(len(set(all_genres)))
# Out:
# 71

# %%
all_genres
# Out:
# ['cult',
#  'horror',
#  'gothic',
#  'murder',
#  'atmospheric',
#  'violence',
#  'romantic',
#  'inspiring',
#  'romantic',
#  'stupid',
#  'feel-good',
#  'cruelty',
#  'murder',
#  'dramatic',
#  'cult',
#  'violence',
#  'atmospheric',
#  'action',
#  'romantic',
#  'revenge',
#  'sadist',
#  'romantic',
#  'queer',
#  'flashback',
#  'gothic',
#  'cruelty',
#  'violence',
#  'cult',
#  'revenge',
#  'sadist',
#  'mystery',
#  'suspenseful',
#  'action',
#  'murder',
#  'flashback',
#  'violence',
#  'revenge',
#  'neo noir',
#  'murder',
#  'violence',
#  'flashback',
#  'cult',
#  'prank',
#  'cult',
#  'psychedelic',
#  'murder',
#  'violence',
#  'tragedy',
#  'dramatic',
#  'murder',
#  'murder',
#  'flashback',
#  'autobiographical',
#  'home movie',
#  'good versus evil',
#  'suspenseful',
#  'depressing',
#  'realism',
#  'boring',
#  'murder',
#  'cult',
#  'violence',
#  'atmospheric',
#  'haunting',
#  'romantic',
#  'sentimental',
#  'flashback',
#  'paranormal',
#  'horror',
#  'haunting',
#  'suspenseful',
#  'neo noir',
#  'murder',
#  'violence',
#  'action',
#  'revenge',
#  'romantic',
#  'historical',
#  'storytelling',
#  'romantic',
#  'home movie',
#  'comedy',
#  'cruelty',
#  'murder',
#  'sadist',
#  'flashback',
#  'revenge',
#  'storytelling',
#  'dramatic',
#  'murder',
#  'fantasy',
#  'murder',
#  'violence',
#  'flashback',
#  'philosophical',
#  'revenge',
#  'historical',
#  'feel-good',
#  'boring',
#  'adult comedy',
#  'cute',
#  'flashback',
#  'romantic',
#  'entertaining',
#  'cult',
#  'comedy',
#  'entertaining',
#  'bleak',
#  'comedy',
#  'humor',
#  'entertaining',
#  'murder',
#  'revenge',
#  'murder',
#  'cult',
#  'stupid',
#  'atmospheric',
#  'violence',
#  'romantic',
#  'cult',
#  'murder',
#  'violence',
#  'prank',
#  'violence',
#  'cult',
#  'murder',
#  'flashback',
#  'psychedelic',
#  'comedy',
#  'murder',
#  'storytelling',
#  'flashback',
#  'violence',
#  'historical',
#  'comedy',
#  'suspenseful',
#  'gothic',
#  'murder',
#  'paranormal',
#  'cult',
#  'violence',
#  'plot twist',
#  'flashback',
#  'good versus evil',
#  'psychedelic',
#  'humor',
#  'revenge',
#  'dramatic',
#  'boring',
#  'paranormal',
#  'suspenseful',
#  'gothic',
#  'flashback',
#  'revenge',
#  'cruelty',
#  'murder',
#  'violence',
#  'romantic',
#  'murder',
#  'flashback',
#  'murder',
#  'violence',
#  'flashback',
#  'good versus evil',
#  'humor',
#  'action',
#  'romantic',
#  'revenge',
#  'entertaining',
#  'comedy',
#  'tragedy',
#  'romantic',
#  'christian film',
#  'tragedy',
#  'pornographic',
#  'murder',
#  'comedy',
#  'gothic',
#  'murder',
#  'cult',
#  'violence',
#  'flashback',
#  'good versus evil',
#  'insanity',
#  'psychedelic',
#  'brainwashing',
#  'sci-fi',
#  'dark',
#  'boring',
#  'gothic',
#  'murder',
#  'mystery',
#  'cult',
#  'violence',
#  'horror',
#  'atmospheric',
#  'action',
#  'claustrophobic',
#  'suspenseful',
#  'sci-fi',
#  'romantic',
#  'entertaining',
#  'violence',
#  'psychedelic',
#  'romantic',
#  'psychological',
#  'flashback',
#  'murder',
#  'violence',
#  'melodrama',
#  'comedy',
#  'boring',
#  'historical fiction',
#  'flashback',
#  'absurd',
#  'humor',
#  'satire',
#  'insanity',
#  'comedy',
#  'suspenseful',
#  'psychedelic',
#  'murder',
#  'comedy',
#  'suspenseful',
#  'mystery',
#  'murder',
#  'cult',
#  'violence',
#  'flashback',
#  'insanity',
#  'humor',
#  'action',
#  'revenge',
#  'good versus evil',
#  'violence',
#  'revenge',
#  'cruelty',
#  'murder',
#  'violence',
#  'brainwashing',
#  'violence',
#  'action',
#  'murder',
#  'flashback',
#  'cult',
#  'romantic',
#  'cult',
#  'violence',
#  'romantic',
#  'comedy',
#  'violence',
#  'cult',
#  'humor',
#  'action',
#  'suspenseful',
#  'revenge',
#  'comedy',
#  'satire',
#  'historical',
#  'flashback',
#  'dark',
#  'suspenseful',
#  'murder',
#  'paranormal',
#  'haunting',
#  'flashback',
#  'psychedelic',
#  'revenge',
#  'storytelling',
#  'dark',
#  'comedy',
#  'neo noir',
#  'murder',
#  'cult',
#  'violence',
#  'entertaining',
#  'sadist',
#  'revenge',
#  'murder',
#  'dramatic',
#  'suspenseful',
#  'mystery',
#  'revenge',
#  'historical',
#  'murder',
#  'cult',
#  'suspenseful',
#  'psychedelic',
#  'claustrophobic',
#  'paranormal',
#  'murder',
#  'comedy',
#  'atmospheric',
#  'romantic',
#  'humor',
#  'entertaining',
#  'boring',
#  'comedy',
#  'boring',
#  'cruelty',
#  'murder',
#  'cult',
#  'violence',
#  'atmospheric',
#  'good versus evil',
#  'action',
#  'sadist',
#  'comedy',
#  'murder',
#  'cult',
#  'alternate reality',
#  'psychedelic',
#  'satire',
#  'alternate history',
#  'cult',
#  'entertaining',
#  'sadist',
#  'romantic',
#  'good versus evil',
#  'cult',
#  'gothic',
#  'murder',
#  'haunting',
#  'good versus evil',
#  'revenge',
#  'cult',
#  'brainwashing',
#  'violence',
#  'satire',
#  'murder',
#  'stupid',
#  'bleak',
#  'cult',
#  'comedy',
#  'satire',
#  'entertaining',
#  'violence',
#  'revenge',
#  'sadist',
#  'fantasy',
#  'gothic',
#  'murder',
#  'boring',
#  'cult',
#  'violence',
#  'good versus evil',
#  'romantic',
#  'fantasy',
#  'murder',
#  'violence',
#  'flashback',
#  'good versus evil',
#  'psychedelic',
#  'humor',
#  'action',
#  'comic',
#  'revenge',
#  'entertaining',
#  'sci-fi',
#  'murder',
#  'violence',
#  'flashback',
#  'good versus evil',
#  'humor',
#  'action',
#  'brainwashing',
#  'suspenseful',
#  'cruelty',
#  'murder',
#  'home movie',
#  'violence',
#  'historical',
#  'murder',
#  'storytelling',
#  'cult',
#  'violence',
#  'dark',
#  'psychological',
#  'grindhouse film',
#  'murder',
#  'cult',
#  'horror',
#  'violence',
#  'insanity',
#  'sadist',
#  'suspenseful',
#  'boring',
#  'murder',
#  'mystery',
#  'thought-provoking',
#  'violence',
#  'flashback',
#  'revenge',
#  'sci-fi',
#  'cult',
#  'romantic',
#  'suspenseful',
#  'violence',
#  'comedy',
#  'cruelty',
#  'murder',
#  'neo noir',
#  'cult',
#  'violence',
#  'flashback',
#  'insanity',
#  'psychedelic',
#  'satire',
#  'romantic',
#  'revenge',
#  'sadist',
#  'entertaining',
#  'revenge',
#  'murder',
#  'violence',
#  'murder',
#  'neo noir',
#  'murder',
#  'cult',
#  'revenge',
#  'violence',
#  'melodrama',
#  'tragedy',
#  'suspenseful',
#  'cult',
#  'violence',
#  'horror',
#  'gothic',
#  'sadist',
#  'insanity',
#  'murder',
#  'flashback',
#  'suspenseful',
#  'neo noir',
#  'murder',
#  'violence',
#  'tragedy',
#  'revenge',
#  'murder',
#  'philosophical',
#  'cult',
#  'murder',
#  'violence',
#  'revenge',
#  'comedy',
#  'murder',
#  'violence',
#  'dark',
#  'gothic',
#  'murder',
#  'neo noir',
#  'cult',
#  'violence',
#  'atmospheric',
#  'good versus evil',
#  'insanity',
#  'suspenseful',
#  'sadist',
#  'home movie',
#  'haunting',
#  'flashback',
#  'flashback',
#  'cult',
#  'murder',
#  'home movie',
#  'violence',
#  'flashback',
#  'mystery',
#  'cruelty',
#  'murder',
#  'flashback',
#  'good versus evil',
#  'insanity',
#  'sadist',
#  'insanity',
#  'psychedelic',
#  'insanity',
#  'gothic',
#  'atmospheric',
#  'haunting',
#  'romantic',
#  'humor',
#  'alternate reality',
#  'queer',
#  'good versus evil',
#  'romantic',
#  'dramatic',
#  'cult',
#  'suspenseful',
#  'comedy',
#  'comedy',
#  'violence',
#  'good versus evil',
#  'psychedelic',
#  'humor',
#  'revenge',
#  'boring',
#  'depressing',
#  'realism',
#  'murder',
#  'stupid',
#  'violence',
#  'queer',
#  'flashback',
#  'tragedy',
#  'romantic',
#  'sentimental',
#  'cult',
#  'comedy',
#  'psychedelic',
#  'violence',
#  'suspenseful',
#  'humor',
#  'murder',
#  'storytelling',
#  'revenge',
#  'gothic',
#  'murder',
#  'violence',
#  'prank',
#  'comedy',
#  'mystery',
#  'neo noir',
#  'cult',
#  'revenge',
#  'violence',
#  'flashback',
#  'good versus evil',
#  'humor',
#  'action',
#  'romantic',
#  'comedy',
#  'fantasy',
#  'cult',
#  'violence',
#  'humor',
#  'satire',
#  'romantic',
#  'entertaining',
#  'good versus evil',
#  'violence',
#  'romantic',
#  'flashback',
#  'cult',
#  'suspenseful',
#  'comedy',
#  'fantasy',
#  'cruelty',
#  'paranormal',
#  'dramatic',
#  'cute',
#  'cult',
#  'clever',
#  'comedy',
#  'humor',
#  'suspenseful',
#  'boring',
#  'violence',
#  'flashback',
#  'action',
#  'revenge',
#  'tragedy',
#  'romantic',
#  'comedy',
#  'murder',
#  'violence',
#  'flashback',
#  'humor',
#  'revenge',
#  'sadist',
#  'dark',
#  'neo noir',
#  'realism',
#  'murder',
#  'bleak',
#  'violence',
#  'flashback',
#  'suspenseful',
#  'psychedelic',
#  'comedy',
#  'cute',
#  'entertaining',
#  'humor',
#  'cult',
#  'romantic',
#  'cult',
#  'comedy',
#  'stupid',
#  'violence',
#  'comic',
#  'comedy',
#  'cruelty',
#  'murder',
#  'cult',
#  'violence',
#  'plot twist',
#  'revenge',
#  'sadist',
#  'plot twist',
#  'mystery',
#  'murder',
#  'good versus evil',
#  'violence',
#  'action',
#  'absurd',
#  'cult',
#  'violence',
#  'comedy',
#  'murder',
#  'realism',
#  'western',
#  'violence',
#  'good versus evil',
#  'humor',
#  'action',
#  'revenge',
#  'sadist',
#  'murder',
#  'home movie',
#  'violence',
#  'murder',
#  'melodrama',
#  'romantic',
#  'cute',
#  'feel-good',
#  'dark',
#  'murder',
#  'dramatic',
#  'violence',
#  'flashback',
#  'philosophical',
#  'historical',
#  'murder',
#  'cult',
#  'atmospheric',
#  'flashback',
#  'good versus evil',
#  'psychedelic',
#  'revenge',
#  'satire',
#  'murder',
#  'paranormal',
#  'violence',
#  'flashback',
#  'good versus evil',
#  'psychedelic',
#  'revenge',
#  'violence',
#  'boring',
#  'historical',
#  'comedy',
#  'murder',
#  'cult',
#  'violence',
#  'psychedelic',
#  'absurd',
#  'satire',
#  'humor',
#  'entertaining',
#  'murder',
#  'violence',
#  'good versus evil',
#  'psychedelic',
#  'action',
#  'suspenseful',
#  'sadist',
#  'flashback',
#  'comedy',
#  'boring',
#  'neo noir',
#  'murder',
#  'dramatic',
#  'cult',
#  'violence',
#  'atmospheric',
#  'psychedelic',
#  'romantic',
#  'suspenseful',
#  'entertaining',
#  'comedy',
#  'dark',
#  'neo noir',
#  'murder',
#  'boring',
#  'suspenseful',
#  'mystery',
#  'dramatic',
#  'violence',
#  'cult',
#  'sadist',
#  'flashback',
#  'psychedelic',
#  'humor',
#  'claustrophobic',
#  'tragedy',
#  'plot twist',
#  'storytelling',
#  'psychedelic',
#  'suspenseful',
#  'violence',
#  'blaxploitation',
#  'murder',
#  'violence',
#  'revenge',
#  'historical fiction',
#  'tragedy',
#  'romantic',
#  'comedy',
#  'murder',
#  'violence',
#  'flashback',
#  'clever',
#  'psychedelic',
#  'action',
#  'revenge',
#  'entertaining',
#  'dark',
#  'fantasy',
#  'mystery',
#  'cult',
#  'violence',
#  'good versus evil',
#  'action',
#  'tragedy',
#  'dark',
#  'comedy',
#  'dramatic',
#  'cult',
#  'violence',
#  'absurd',
#  'humor',
#  'satire',
#  'psychedelic',
#  'suspenseful',
#  'entertaining',
#  'comedy',
#  'murder',
#  'cult',
#  'satire',
#  'romantic',
#  'home movie',
#  'cruelty',
#  'murder',
#  'violence',
#  'flashback',
#  'insanity',
#  'absurd',
#  'romantic',
#  'revenge',
#  'sadist',
#  'humor',
#  'comedy',
#  'murder',
#  'stupid',
#  'cult',
#  'violence',
#  'good versus evil',
#  'entertaining',
#  'psychedelic',
#  'comedy',
#  'psychological',
#  'stupid',
#  'whimsical',
#  'dramatic',
#  'cult',
#  'cute',
#  'clever',
#  'flashback',
#  'historical fiction',
#  'psychedelic',
#  'humor',
#  'action',
#  'feel-good',
#  'melodrama',
#  'inspiring',
#  'romantic',
#  'historical',
#  'entertaining',
#  'sentimental',
#  'psychological',
#  'murder',
#  'violence',
#  'cult',
#  'flashback',
#  'clever',
#  'philosophical',
#  'sadist',
#  'comedy',
#  'boring',
#  'psychological',
#  'satire',
#  'flashback',
#  'comedy',
#  'cult',
#  'revenge',
#  'action',
#  'murder',
#  'cult',
#  'revenge',
#  'psychedelic',
#  'flashback',
#  'romantic',
#  'flashback',
#  'dark',
#  'comedy',
#  'neo noir',
#  'murder',
#  'cult',
#  'sadist',
#  'violence',
#  'flashback',
#  'claustrophobic',
#  'revenge',
#  'storytelling',
#  'fantasy',
#  'sentimental',
#  'flashback',
#  'romantic',
#  'historical',
#  'revenge',
#  'murder',
#  'suspenseful',
#  'murder',
#  'bleak',
#  'violence',
#  'cult',
#  'atmospheric',
#  'romantic',
#  'revenge',
#  'cult',
#  'violence',
#  'revenge',
#  'prank',
#  'pornographic',
#  'violence',
#  'intrigue',
#  'murder',
#  'gothic',
#  'murder',
#  'realism',
#  'cult',
#  'violence',
#  'good versus evil',
#  'plot twist',
#  'sadist',
#  'sci-fi',
#  'romantic',
#  'mystery',
#  'action',
#  'sci-fi',
#  'cult',
#  'historical',
#  'violence',
#  'murder',
#  'romantic',
#  'satire',
#  'fantasy',
#  'allegory',
#  'cult',
#  'flashback',
#  'psychedelic',
#  'sadist',
#  'fantasy',
#  'psychological',
#  'murder',
#  'boring',
#  'cult',
#  'violence',
#  'revenge',
#  'flashback',
#  'insanity',
#  'psychedelic',
#  'melodrama',
#  'romantic',
#  'queer',
#  'neo noir',
#  'murder',
#  'flashback',
#  'cult',
#  'cruelty',
#  'violence',
#  'psychedelic',
#  'cult',
#  'good versus evil',
#  'paranormal',
#  'murder',
#  'psychedelic',
#  'cute',
#  'entertaining',
#  'romantic',
#  'neo noir',
#  'murder',
#  'violence',
#  'flashback',
#  'suspenseful',
#  'sadist',
#  'psychedelic',
#  'mystery',
#  'gothic',
#  'murder',
#  'neo noir',
#  'bleak',
#  'dramatic',
#  'cult',
#  'violence',
#  'action',
#  'romantic',
#  'suspenseful',
#  'alternate history',
#  'sci-fi',
#  'insanity',
#  'cult',
#  'violence',
#  'murder',
#  'stupid',
#  'paranormal',
#  'anti war',
#  'cult',
#  'violence',
#  'atmospheric',
#  'flashback',
#  'psychedelic',
#  'action',
#  'romantic',
#  'comic',
#  'revenge',
#  'alternate history',
#  'sci-fi',
#  'bleak',
#  'insanity',
#  'atmospheric',
#  'cult',
#  'entertaining',
#  'murder',
#  'cult',
#  'violence',
#  'flashback',
#  'historical',
#  'blaxploitation',
#  'neo noir',
#  'murder',
#  'thought-provoking',
#  'cult',
#  'revenge',
#  'violence',
#  'flashback',
#  'suspenseful',
#  'sadist',
#  'cult',
#  'boring',
#  'murder',
#  'mystery',
#  'neo noir',
#  'murder',
#  'realism',
#  'dramatic',
#  'violence',
#  'romantic',
#  'suspenseful',
#  'cult',
#  'action',
#  'murder',
#  'boring',
#  'violence',
#  'murder',
#  'melodrama',
#  'humor',
#  'romantic',
#  'murder',
#  'prank',
#  'romantic',
#  'anti war',
#  'romantic',
#  'avant garde',
#  'murder',
#  'mystery',
#  'suspenseful',
#  'psychological',
#  'flashback',
#  'dark',
#  'psychological',
#  'neo noir',
#  'mystery',
#  'atmospheric',
#  'plot twist',
#  'psychedelic',
#  'action',
#  'tragedy',
#  'suspenseful',
#  'fantasy',
#  'boring',
#  'violence',
#  'intrigue',
#  'alternate reality',
#  'psychedelic',
#  'storytelling',
#  'sci-fi',
#  'cult',
#  'murder',
#  'violence',
#  ...]

# %%
all_genres = nltk.FreqDist(all_genres)
all_genres_df = pd.DataFrame({'Genre': list(all_genres.keys()), 'Count': list(all_genres.values())})

# %%
plt.style.use('ggplot')
g = all_genres_df.nlargest(columns='Count', n=15)
plt.figure(figsize=(20,5))
ax = sns.barplot(data=g, x='Genre', y='Count')
ax.set(ylabel='Count')
plt.show()

# %%
# function untuk text cleaning 
def clean_text(text):
    # remove backslash-apostrophe 
    text = re.sub("\'", "", text) 
    # remove everything except alphabets 
    text = re.sub("[^a-zA-Z]"," ",text) 
    # remove whitespaces 
    text = ' '.join(text.split()) 
    # convert text ke lowercase 
    text = text.lower() 
    return text

# %%
import copy
movies_new = copy.deepcopy(movies)
movies_new['clean_plot'] = movies['plot'].apply(lambda x: clean_text(x))
movies_new.head()
# Out:
#      imdb_id                                               plot  \
# 0  tt0057603  Note: this synopsis is for the orginal Italian...
# 1  tt1733125  Two thousand years ago, Nhagruul the Foul, a s...
# 2  tt0033045  Matuschek's, a gift store in Budapest, is the ...
# 3  tt0113862  Glenn Holland, not a morning person by anyone'...
# 4  tt0086250  In May 1980, a Cuban man named Tony Montana (A...
#
#                                            title  \
# 0                        I tre volti della paura
# 1  Dungeons & Dragons: The Book of Vile Darkness
# 2                     The Shop Around the Corner
# 3                             Mr. Holland's Opus
# 4                                       Scarface
#
#                                                 tags  split  \
# 0    [cult,  horror,  gothic,  murder,  atmospheric]  train
# 1                                         [violence]  train
# 2                                         [romantic]   test
# 3        [inspiring,  romantic,  stupid,  feel-good]  train
# 4  [cruelty,  murder,  dramatic,  cult,  violence...    val
#
#                                           clean_plot
# 0  note this synopsis is for the orginal italian ...
# 1  two thousand years ago nhagruul the foul a sor...
# 2  matuscheks a gift store in budapest is the wor...
# 3  glenn holland not a morning person by anyones ...
# 4  in may a cuban man named tony montana al pacin...

# %%
def freq_words(x, terms = 15):
    all_words = ' '.join([text for text in x]) 
    all_words = all_words.split() 
    fdist = nltk.FreqDist(all_words) 
    words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())}) 
  
    # selecting top 15 most frequent words 
    d = words_df.nlargest(columns="count", n = terms) 
  
    # visualize words and frequencies
    plt.figure(figsize=(15,5)) 
    ax = sns.barplot(data=d, x= "word", y = "count") 
    ax.set(ylabel = 'Count') 
    plt.show()

# %%
#print 15 most frequent words 
freq_words(movies_new['clean_plot'], 15)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# function to remove stopwords
def remove_stopwords(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    return ' '.join(no_stopword_text)

movies_new['clean_plot'] = movies_new['clean_plot'].apply(lambda x: remove_stopwords(x))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Widows\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
freq_words(movies_new['clean_plot'], 15)

# %%
mlb = MultiLabelBinarizer()
mlb.fit(movies_new[movies_new['split'] == 'train']['tags'])
y = mlb.transform(movies_new[movies_new['split'] == 'train']['tags'])

# %%
y.shape
# Out:
# (9489, 142)

# %%
movies_new = pd.concat([movies_new, pd.DataFrame(y, columns=mlb.classes_)], axis=1)
print(len(movies_new.columns))
movies_new.columns
# Out:
# 148
# Index(['imdb_id', 'plot', 'title', 'tags', 'split', 'clean_plot', ' absurd',
#        ' action', ' adult comedy', ' allegory',
#        ...
#        'sentimental', 'storytelling', 'stupid', 'suicidal', 'suspenseful',
#        'thought-provoking', 'tragedy', 'violence', 'western', 'whimsical'],
#       dtype='object', length=148)

# %%
counts = []
genres = mlb.classes_
split = []
for genre in genres:
    counts.append((genre, movies_new[genre].sum()))
movies_new_stats = pd.DataFrame(counts, columns=['genres', 'plots'])

# %%
print(len(movies_new.columns))
genres = movies_new_stats.loc[movies_new_stats['plots'] > 100, 'genres'].tolist()
movies_new.drop(movies_new_stats.loc[movies_new_stats['plots'] < 100, 'genres'].tolist(), axis=1, inplace=True)
len(movies_new.columns)
# Out:
# 148
# 66

# %%
mlb = MultiLabelBinarizer()
mlb.fit(movies_new[movies_new['split'] == 'train']['tags'])
# Out:
# MultiLabelBinarizer()

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=10000)

# %%
y = movies_new[movies_new['split'] == 'train'].iloc[:, 6:len(movies_new.columns)+1]
y.fillna(1, inplace=True)
y = np.array(y)

# %%
xtrain_tfidf = tfidf_vectorizer.fit_transform(movies_new[movies_new['split'] == 'train']['clean_plot'])
xtrain_tfidf
# Out:
# <9489x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2420734 stored elements in Compressed Sparse Row format>

# %%
xtest_tfidf = tfidf_vectorizer.fit_transform(movies_new[movies_new['split'] == 'test']['clean_plot'])
xtest_tfidf
# Out:
# <2966x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 768417 stored elements in Compressed Sparse Row format>

# %%
clf = MultinomialNB()

# %%
i = 0
t = []

while i <= y.shape[1]-1:
    s = []
    clf.fit(xtrain_tfidf, y[:,i])
    s.append(clf.predict(xtest_tfidf))
    i += 1
    t.append(s)

# %%
y_pred = np.array(t).reshape(np.array(t).shape[2], np.array(t).shape[0])
y_pred.shape
# Out:
# (2966, 60)

# %%
y_true = movies_new[movies_new['split'] == 'test'].iloc[:, 6:len(movies_new.columns)+1]
y_true.fillna(1, inplace=True)

# %%
y_true = np.array(y_true)

# %%
print(y_pred.shape)
print(y_true.shape)
# Out:
# (2966, 60)
# (2966, 60)

# %%
sklearn.metrics.f1_score(y_true, y_pred, average='micro')
# Out:
# 0.3442324350142074

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.31      0.34      1071
#            1       0.39      0.32      0.35      1130
#            2       0.36      0.31      0.33      1066
#            3       0.38      0.32      0.35      1095
#            4       0.38      0.33      0.35      1099
#            5       0.38      0.32      0.35      1133
#            6       0.37      0.31      0.33      1089
#            7       0.40      0.29      0.34      1252
#            8       0.36      0.30      0.33      1072
#            9       0.37      0.31      0.34      1074
#           10       0.37      0.30      0.33      1122
#           11       0.39      0.33      0.36      1089
#           12       0.47      0.31      0.37      1377
#           13       0.37      0.30      0.33      1109
#           14       0.38      0.31      0.34      1102
#           15       0.37      0.30      0.33      1084
#           16       0.37      0.32      0.34      1098
#           17       0.37      0.30      0.33      1146
#           18       0.35      0.29      0.32      1097
#           19       0.38      0.32      0.34      1090
#           20       0.55      0.31      0.40      1623
#           21       0.38      0.32      0.35      1094
#           22       0.40      0.33      0.36      1124
#           23       0.36      0.32      0.34      1078
#           24       0.36      0.31      0.33      1083
#           25       0.35      0.30      0.32      1082
#           26       0.40      0.32      0.35      1190
#           27       0.37      0.32      0.34      1075
#           28       0.35      0.31      0.33      1075
#           29       0.41      0.31      0.35      1211
#           30       0.43      0.32      0.37      1228
#           31       0.39      0.32      0.35      1129
#           32       0.39      0.32      0.35      1119
#           33       0.36      0.31      0.33      1083
#           34       0.37      0.32      0.35      1078
#           35       0.38      0.31      0.34      1090
#           36       0.36      0.32      0.34      1070
#           37       0.39      0.31      0.35      1142
#           38       0.37      0.32      0.34      1085
#           39       0.46      0.30      0.36      1406
#           40       0.42      0.32      0.36      1210
#           41       0.40      0.31      0.35      1197
#           42       0.37      0.31      0.34      1091
#           43       0.36      0.31      0.33      1073
#           44       0.37      0.31      0.34      1090
#           45       0.39      0.33      0.36      1098
#           46       0.39      0.32      0.36      1108
#           47       0.36      0.31      0.34      1088
#           48       0.35      0.30      0.33      1072
#           49       0.40      0.30      0.34      1230
#           50       0.35      0.30      0.32      1085
#           51       0.35      0.30      0.32      1075
#           52       0.37      0.32      0.34      1082
#           53       0.40      0.34      0.37      1135
#           54       0.41      0.31      0.35      1192
#           55       0.41      0.30      0.35      1240
#           56       0.36      0.31      0.33      1072
#           57       0.37      0.31      0.34      1101
#           58       0.38      0.32      0.34      1098
#           59       0.43      0.31      0.36      1280
#
#    micro avg       0.38      0.31      0.34     68077
#    macro avg       0.38      0.31      0.34     68077
# weighted avg       0.39      0.31      0.34     68077
#  samples avg       0.38      0.29      0.21     68077
# D:\Application\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
sklearn.metrics.multilabel_confusion_matrix(y_true, y_pred)
# Out:
# array([[[1317,  578],
#         [ 738,  333]],
#
#        [[1277,  559],
#         [ 771,  359]],
#
#        [[1312,  588],
#         [ 734,  332]],
#
#        [[1293,  578],
#         [ 746,  349]],
#
#        [[1284,  583],
#         [ 741,  358]],
#
#        [[1259,  574],
#         [ 775,  358]],
#
#        [[1299,  578],
#         [ 754,  335]],
#
#        [[1164,  550],
#         [ 888,  364]],
#
#        [[1306,  588],
#         [ 748,  324]],
#
#        [[1308,  584],
#         [ 737,  337]],
#
#        [[1263,  581],
#         [ 781,  341]],
#
#        [[1327,  550],
#         [ 735,  354]],
#
#        [[1099,  490],
#         [ 949,  428]],
#
#        [[1282,  575],
#         [ 776,  333]],
#
#        [[1298,  566],
#         [ 757,  345]],
#
#        [[1314,  568],
#         [ 754,  330]],
#
#        [[1272,  596],
#         [ 745,  353]],
#
#        [[1227,  593],
#         [ 803,  343]],
#
#        [[1267,  602],
#         [ 775,  322]],
#
#        [[1308,  568],
#         [ 746,  344]],
#
#        [[ 931,  412],
#         [1115,  508]],
#
#        [[1286,  586],
#         [ 740,  354]],
#
#        [[1281,  561],
#         [ 757,  367]],
#
#        [[1275,  613],
#         [ 733,  345]],
#
#        [[1290,  593],
#         [ 749,  334]],
#
#        [[1286,  598],
#         [ 760,  322]],
#
#        [[1212,  564],
#         [ 813,  377]],
#
#        [[1304,  587],
#         [ 731,  344]],
#
#        [[1278,  613],
#         [ 742,  333]],
#
#        [[1211,  544],
#         [ 833,  378]],
#
#        [[1210,  528],
#         [ 831,  397]],
#
#        [[1279,  558],
#         [ 771,  358]],
#
#        [[1279,  568],
#         [ 762,  357]],
#
#        [[1275,  608],
#         [ 746,  337]],
#
#        [[1306,  582],
#         [ 731,  347]],
#
#        [[1318,  558],
#         [ 755,  335]],
#
#        [[1295,  601],
#         [ 732,  338]],
#
#        [[1257,  567],
#         [ 784,  358]],
#
#        [[1299,  582],
#         [ 740,  345]],
#
#        [[1063,  497],
#         [ 983,  423]],
#
#        [[1220,  536],
#         [ 826,  384]],
#
#        [[1203,  566],
#         [ 820,  377]],
#
#        [[1303,  572],
#         [ 753,  338]],
#
#        [[1297,  596],
#         [ 744,  329]],
#
#        [[1289,  587],
#         [ 749,  341]],
#
#        [[1314,  554],
#         [ 740,  358]],
#
#        [[1302,  556],
#         [ 748,  360]],
#
#        [[1287,  591],
#         [ 749,  339]],
#
#        [[1303,  591],
#         [ 748,  324]],
#
#        [[1176,  560],
#         [ 861,  369]],
#
#        [[1283,  598],
#         [ 759,  326]],
#
#        [[1301,  590],
#         [ 752,  323]],
#
#        [[1281,  603],
#         [ 735,  347]],
#
#        [[1269,  562],
#         [ 753,  382]],
#
#        [[1229,  545],
#         [ 820,  372]],
#
#        [[1206,  520],
#         [ 872,  368]],
#
#        [[1294,  600],
#         [ 738,  334]],
#
#        [[1271,  594],
#         [ 758,  343]],
#
#        [[1290,  578],
#         [ 749,  349]],
#
#        [[1165,  521],
#         [ 881,  399]]], dtype=int64)
